# %% [markdown]
# # Parte 2: Data Science

# %% [markdown]
# ## **Sumário**
#
# * 1. Lendo Base de Dados
# * 2. Análise exploratória
#     * 2.1. Entendendo as Variáveis
#     * 2.2. Entendendo Variáveis de receita bruta e margem
# * 3. Respondendo: 10 itens de maior relevância e os top 15 itens que acompanham cada um deles
#     * 3.1. Market Basket Analysis

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('/home/rafaelfabrichimidt/Documentos/Projetos/Python/codigos/case/analytics_engineer_carrefour/tutorial/CASE_PRATICO_SAMS_CLUB.csv')

df['periodo'] = pd.to_datetime(df['periodo'])


indices = df[df['item_unidade'] <= 0].index

df.drop(labels = indices, axis = 0, inplace = True)

print('Qtd de linhas = ', df.shape[0])
print('Qtd de colunas = ', df.shape[1])
# Out:
# Qtd de linhas =  874860
# Qtd de colunas =  11

# %%
df.head()
# Out:
#       periodo  id_clube              socio canal                     ticket  \
# 0  2022-01-10      5235  45765100809381908  PISO  4576510080938190820220110
# 1  2022-01-10      5235  45766100903265726  PISO  4576610090326572620220110
# 2  2022-01-10      5235  45765100815078019  PISO  4576510081507801920220110
# 3  2022-01-10      5235  45766100904345030  PISO  4576610090434503020220110
# 4  2022-01-10      5235  45766100903286284  PISO  4576610090328628420220110
#
#      departamento  item_id   item_descricao  item_unidade  receita_bruta  \
# 0  BAZAR E TÊXTIL  1259475           CALCAO             2          81.17
# 1  BAZAR E TÊXTIL  1259475           CALCAO             1          41.27
# 2  BAZAR E TÊXTIL  1225017     CHAPEU PRAIA             1          51.27
# 3  BAZAR E TÊXTIL  1216504   BANCO DOBRAVEL             1          81.34
# 4  BAZAR E TÊXTIL  1259473  BERMUDA MOLETOM             2         201.17
#
#    margem
# 0   22.43
# 1   11.90
# 2   11.10
# 3   22.93
# 4   46.37

# %%
df.nunique()
# Out:
# periodo               3
# id_clube             42
# socio             71735
# canal                 2
# ticket            75183
# departamento          8
# item_id           10620
# item_descricao    10215
# item_unidade        119
# receita_bruta     15413
# margem            13633
# dtype: int64

# %%
10620 / 3
# Out:
# 3540.0

# %%
df[['socio','periodo','ticket', 'item_descricao']].copy()

# %%
df['cesta'] = df['socio'].astype('str') + '-' + df['ticket'].astype('str')

# %%
support_A = df.groupby(['item_descricao'])['item_unidade'].sum().sort_values(ascending = False)[0:10] / df.shape[0]
dic_support_A = dict(support_A)
dic_support_A
# Out:
# {'SACOLA PLASTICA MM BRANCA': 0.03334819285371374,
#  'SACOLA PLASTICA MM CINZA': 0.009388930800356628,
#  'PAPEL TOALHA KITCHEN JUMB FD C360FL': 0.008732825823560341,
#  'SACOLA PLASTICA MM VERDE': 0.008645954781336443,
#  'CR DE LEITE PIRACANJUBA TP 200G': 0.008372768214342866,
#  'OLEO SOJA LIZA PET 900ML': 0.007901835722286995,
#  'CERV QUILMES CLASSICA LN 340ML': 0.00673364881238141,
#  'PAPEL REPORT MULT A4 BRANCO 500 F': 0.006707358891708388,
#  'ACUC REF UNIAO 1KG': 0.006468463525592666,
#  'MM LAVA ROUPAS 5LTS ULTIMATE CLEAN': 0.0060272500742976015}

# %%
_10_items_mais_relevantes = support_A.keys().values.tolist()

# %%
qtd_total = df.shape[0]
dic_support_A_B = {}
limite = 0.0002

for item in _10_items_mais_relevantes:
    
    print(item)

    #filtrar as cestas que possuem esse item 
    cestas = df[df['item_descricao'] == item]['cesta'].values.tolist()
    
    #filtrar apenas essas cestas
    df_cestas = df[df['cesta'].isin(cestas)].copy()

    #contar os items que mais aparecem nessa cesta (pegar os 15 primeiros) 
    qtd_para_confidence = df_cestas['item_descricao'].value_counts()

    #qtd de cestas que o item (X) aparece
    #qtd_cestas = df_cestas.shape[0]

    dic_uniao = dict(qtd_para_confidence / qtd_total)

    dic_uniao_acima_limite = {k : v for k, v in dic_uniao.items() if v > limite}

    dic_support_A_B[item] = dic_uniao_acima_limite
# Out:
# SACOLA PLASTICA MM BRANCA
# SACOLA PLASTICA MM CINZA
# PAPEL TOALHA KITCHEN JUMB FD C360FL
# SACOLA PLASTICA MM VERDE
# CR DE LEITE PIRACANJUBA TP 200G
# OLEO SOJA LIZA PET 900ML
# CERV QUILMES CLASSICA LN 340ML
# PAPEL REPORT MULT A4 BRANCO 500 F
# ACUC REF UNIAO 1KG
# MM LAVA ROUPAS 5LTS ULTIMATE CLEAN

# %%
df_support_A_B = pd.DataFrame.from_dict(dic_support_A_B, orient = 'index')
colunas = df_support_A_B.columns
df_support_A_B.reset_index(inplace = True)
df_support_A_B.rename(columns = {'index': 'B'}, inplace = True)
df_support_A_B = pd.melt(df_support_A_B, id_vars = 'B', value_vars = colunas)
df_support_A_B.rename(columns = {'variable':'A'}, inplace = True)
df_support_A_B.dropna(inplace = True)
indices = df_support_A_B[df_support_A_B['A'] == df_support_A_B['B']].index
df_support_A_B.drop(labels = indices, axis = 0, inplace  = True)
df_support_A_B.reset_index(drop = True, inplace = True)

# %%
df_support_A_B
# Out:
#                                        B                                A  \
# 0    PAPEL TOALHA KITCHEN JUMB FD C360FL        SACOLA PLASTICA MM BRANCA
# 1        CR DE LEITE PIRACANJUBA TP 200G        SACOLA PLASTICA MM BRANCA
# 2               OLEO SOJA LIZA PET 900ML        SACOLA PLASTICA MM BRANCA
# 3      PAPEL REPORT MULT A4 BRANCO 500 F        SACOLA PLASTICA MM BRANCA
# 4                     ACUC REF UNIAO 1KG        SACOLA PLASTICA MM BRANCA
# ..                                   ...                              ...
# 290  PAPEL TOALHA KITCHEN JUMB FD C360FL  VANISH 3 LT COLORS TIRA MANCHAS
# 291  PAPEL TOALHA KITCHEN JUMB FD C360FL  LYSOFORM BRUTO DESINFETANTE 5LT
# 292  PAPEL TOALHA KITCHEN JUMB FD C360FL    ACUC DEME ORGANICO NATIVE 1KG
# 293  PAPEL TOALHA KITCHEN JUMB FD C360FL           SAPOLIO RADIUM 2X450ML
# 294   MM LAVA ROUPAS 5LTS ULTIMATE CLEAN                MM MULTIUSO 1.1LT
#
#         value
# 0    0.001447
# 1    0.000430
# 2    0.000287
# 3    0.000370
# 4    0.000274
# ..        ...
# 290  0.000217
# 291  0.000211
# 292  0.000203
# 293  0.000201
# 294  0.000214
#
# [295 rows x 3 columns]

# %%
dic_support_A_B_C = {}
dic_support_A_B_C_sem_limite = {}

for i in range(0, df_support_A_B.shape[0], 1):
    item_A = df_support_A_B.loc[i, 'A']
    item_B = df_support_A_B.loc[i, 'B']
    print('item A = {}'.format(item_A))
    print('item B = {}'.format(item_B))

    #filtrar as cestas que possuem esse item 
    cestas = df[(df['item_descricao'] == item_A)]['cesta'].values.tolist()
    
    #filtrar apenas essas cestas
    df_cestas = df[df['cesta'].isin(cestas)].copy()

    cestas = df_cestas[(df_cestas['item_descricao'] == item_B)]['cesta'].values.tolist()

    df_cestas = df[df['cesta'].isin(cestas)].copy()

    #contar os items que mais aparecem nessa cesta (pegar os 15 primeiros) 
    qtd_para_confidence = df_cestas['item_descricao'].value_counts()
        
    dic_uniao = dict(qtd_para_confidence / qtd_total)

    dic_uniao.pop(item_A)
    dic_uniao.pop(item_B)
        
    dic_uniao_acima_limite = {k : v for k, v in dic_uniao.items() if v > limite}

    dic_support_A_B_C[item_A + '-' + item_B] = dic_uniao_acima_limite
# Out:
# item A = SACOLA PLASTICA MM BRANCA
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = SACOLA PLASTICA MM BRANCA
# item B = CR DE LEITE PIRACANJUBA TP 200G
# item A = SACOLA PLASTICA MM BRANCA
# item B = OLEO SOJA LIZA PET 900ML
# item A = SACOLA PLASTICA MM BRANCA
# item B = PAPEL REPORT MULT A4 BRANCO 500 F
# item A = SACOLA PLASTICA MM BRANCA
# item B = ACUC REF UNIAO 1KG
# item A = SACOLA PLASTICA MM BRANCA
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item B = SACOLA PLASTICA MM BRANCA
# item A = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item B = CR DE LEITE PIRACANJUBA TP 200G
# item A = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item B = OLEO SOJA LIZA PET 900ML
# item A = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item B = PAPEL REPORT MULT A4 BRANCO 500 F
# item A = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item B = ACUC REF UNIAO 1KG
# item A = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item B = SACOLA PLASTICA MM CINZA
# item A = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item B = SACOLA PLASTICA MM VERDE
# item A = PAO FRANCES MEMBERS MARK
# item B = SACOLA PLASTICA MM BRANCA
# item A = PAO FRANCES MEMBERS MARK
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = PAO FRANCES MEMBERS MARK
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = PAO FRANCES MEMBERS MARK
# item B = SACOLA PLASTICA MM VERDE
# item A = BANANA PRATA KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = BANANA PRATA KG
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = BANANA PRATA KG
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = BANANA PRATA KG
# item B = SACOLA PLASTICA MM CINZA
# item A = BANANA PRATA KG
# item B = SACOLA PLASTICA MM VERDE
# item A = REQUEIJ CREMOSO 500G MEMBERS MARK
# item B = SACOLA PLASTICA MM BRANCA
# item A = REQUEIJ CREMOSO 500G MEMBERS MARK
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = REQUEIJ CREMOSO 500G MEMBERS MARK
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = REQUEIJ CREMOSO 500G MEMBERS MARK
# item B = SACOLA PLASTICA MM VERDE
# item A = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item B = SACOLA PLASTICA MM BRANCA
# item A = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item B = CR DE LEITE PIRACANJUBA TP 200G
# item A = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item B = ACUC REF UNIAO 1KG
# item A = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item B = SACOLA PLASTICA MM CINZA
# item A = PH NEVE FT 20M L32P28UN
# item B = SACOLA PLASTICA MM BRANCA
# item A = PH NEVE FT 20M L32P28UN
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = PH NEVE FT 20M L32P28UN
# item B = CR DE LEITE PIRACANJUBA TP 200G
# item A = PH NEVE FT 20M L32P28UN
# item B = OLEO SOJA LIZA PET 900ML
# item A = PH NEVE FT 20M L32P28UN
# item B = ACUC REF UNIAO 1KG
# item A = PH NEVE FT 20M L32P28UN
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = PH NEVE FT 20M L32P28UN
# item B = SACOLA PLASTICA MM CINZA
# item A = PH NEVE FT 20M L32P28UN
# item B = SACOLA PLASTICA MM VERDE
# item A = MANTEIGA COM SAL MEMBERS MARK 500G
# item B = SACOLA PLASTICA MM BRANCA
# item A = MANTEIGA COM SAL MEMBERS MARK 500G
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = MANTEIGA COM SAL MEMBERS MARK 500G
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = FILE PEITO FRANGO SADIA 1KG ZIP IQF
# item B = SACOLA PLASTICA MM BRANCA
# item A = FILE PEITO FRANGO SADIA 1KG ZIP IQF
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = FILE PEITO FRANGO SADIA 1KG ZIP IQF
# item B = CR DE LEITE PIRACANJUBA TP 200G
# item A = FILE PEITO FRANGO SADIA 1KG ZIP IQF
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = PH PERSONAL VIP FD 40 ROLOSX30M
# item B = SACOLA PLASTICA MM BRANCA
# item A = PH PERSONAL VIP FD 40 ROLOSX30M
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = PH PERSONAL VIP FD 40 ROLOSX30M
# item B = CR DE LEITE PIRACANJUBA TP 200G
# item A = PH PERSONAL VIP FD 40 ROLOSX30M
# item B = OLEO SOJA LIZA PET 900ML
# item A = PH PERSONAL VIP FD 40 ROLOSX30M
# item B = ACUC REF UNIAO 1KG
# item A = PH PERSONAL VIP FD 40 ROLOSX30M
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = PH PERSONAL VIP FD 40 ROLOSX30M
# item B = SACOLA PLASTICA MM CINZA
# item A = OMO LAVA ROUPAS LAVAG PERFEITA 5LT
# item B = SACOLA PLASTICA MM BRANCA
# item A = OMO LAVA ROUPAS LAVAG PERFEITA 5LT
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = OMO LAVA ROUPAS LAVAG PERFEITA 5LT
# item B = ACUC REF UNIAO 1KG
# item A = OMO LAVA ROUPAS LAVAG PERFEITA 5LT
# item B = SACOLA PLASTICA MM CINZA
# item A = BISC CH PETIT BEURRE GRIESSON 150G
# item B = SACOLA PLASTICA MM BRANCA
# item A = BISC CH PETIT BEURRE GRIESSON 150G
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = BISC CH PETIT BEURRE GRIESSON 150G
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = LEITE FERMENTADO YAKULT 6X80G
# item B = SACOLA PLASTICA MM BRANCA
# item A = LEITE FERMENTADO YAKULT 6X80G
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = LEITE FERMENTADO YAKULT 6X80G
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = REQUEIJAO TRADIC CATUPIRY 500G
# item B = SACOLA PLASTICA MM BRANCA
# item A = REQUEIJAO TRADIC CATUPIRY 500G
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = REQUEIJAO TRADIC CATUPIRY 500G
# item B = CR DE LEITE PIRACANJUBA TP 200G
# item A = REQUEIJAO TRADIC CATUPIRY 500G
# item B = ACUC REF UNIAO 1KG
# item A = REQUEIJAO TRADIC CATUPIRY 500G
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = ALCOOL LIQ BACT 70 INPM TOPFORM 1L
# item B = SACOLA PLASTICA MM BRANCA
# item A = ALCOOL LIQ BACT 70 INPM TOPFORM 1L
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = ALCOOL LIQ BACT 70 INPM TOPFORM 1L
# item B = ACUC REF UNIAO 1KG
# item A = ALCOOL LIQ BACT 70 INPM TOPFORM 1L
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = QJ MUSS INTERFOLHADA KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = QJ MUSS INTERFOLHADA KG
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = CENOURA KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = CENOURA KG
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = CENOURA KG
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = SUCO DE LARANJA INTEGRAL 2L
# item B = SACOLA PLASTICA MM BRANCA
# item A = SUCO DE LARANJA INTEGRAL 2L
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = SUCO DE LARANJA INTEGRAL 2L
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = CEBOLA KG KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = PAO ITALIANO MEMBERS MARK
# item B = SACOLA PLASTICA MM BRANCA
# item A = LIMPOL 6X500ML DETERG LIQ NATURAL
# item B = SACOLA PLASTICA MM BRANCA
# item A = LIMPOL 6X500ML DETERG LIQ NATURAL
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = LIMPOL 6X500ML DETERG LIQ NATURAL
# item B = CR DE LEITE PIRACANJUBA TP 200G
# item A = LIMPOL 6X500ML DETERG LIQ NATURAL
# item B = ACUC REF UNIAO 1KG
# item A = LIMPOL 6X500ML DETERG LIQ NATURAL
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = BANANA NANICA KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = BANANA NANICA KG
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = BANANA NANICA KG
# item B = SACOLA PLASTICA MM CINZA
# item A = BATATA PALITO 2KG MCCAIN
# item B = SACOLA PLASTICA MM BRANCA
# item A = BATATA PALITO 2KG MCCAIN
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = BISC POLV SALGADO 300G MEMBERS MARK
# item B = SACOLA PLASTICA MM BRANCA
# item A = BISC POLV SALGADO 300G MEMBERS MARK
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = CR DE LEITE PIRACANJUBA TP 200G
# item B = SACOLA PLASTICA MM BRANCA
# item A = CR DE LEITE PIRACANJUBA TP 200G
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = CR DE LEITE PIRACANJUBA TP 200G
# item B = ACUC REF UNIAO 1KG
# item A = CR DE LEITE PIRACANJUBA TP 200G
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = SUCO OQ UVA INTEGRAL 1,5L
# item B = SACOLA PLASTICA MM BRANCA
# item A = BATATA PALITO 2KG MEMBERS MARK
# item B = SACOLA PLASTICA MM BRANCA
# item A = PAPEL TOALHA SNOB HIPER 360 FLS
# item B = SACOLA PLASTICA MM BRANCA
# item A = LEITE COND MOCA LT 395G
# item B = SACOLA PLASTICA MM BRANCA
# item A = LEITE COND MOCA LT 395G
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = LEITE COND MOCA LT 395G
# item B = CR DE LEITE PIRACANJUBA TP 200G
# item A = LEITE COND MOCA LT 395G
# item B = ACUC REF UNIAO 1KG
# item A = WAFFLE TRAD 525G FORNO DE MINAS
# item B = SACOLA PLASTICA MM BRANCA
# item A = WAFFLE TRAD 525G FORNO DE MINAS
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = KETCHUP HEINZ 1.033KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = KETCHUP HEINZ 1.033KG
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = CREME DENTAL TRIPLA ACAO 6X90G COLG
# item B = SACOLA PLASTICA MM BRANCA
# item A = CREME DENTAL TRIPLA ACAO 6X90G COLG
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = CREME DENTAL TRIPLA ACAO 6X90G COLG
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = SUCO NATURAL ONE LARANJA 2L
# item B = SACOLA PLASTICA MM BRANCA
# item A = PAPEL REPORT MULT A4 BRANCO 500 F
# item B = SACOLA PLASTICA MM BRANCA
# item A = PAPEL REPORT MULT A4 BRANCO 500 F
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = MAMAO PAPAYA KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = SHAMPOO ALTA MODA BB CREAM 1LT
# item B = SACOLA PLASTICA MM BRANCA
# item A = BRIOCHE FRANCES MEMBERS MARK
# item B = SACOLA PLASTICA MM BRANCA
# item A = FILTRO DE PAPEL120UN MM TAM 103
# item B = SACOLA PLASTICA MM BRANCA
# item A = FILTRO DE PAPEL120UN MM TAM 103
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = FILTRO DE PAPEL120UN MM TAM 103
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = BATATA ESPECIAL KG KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = LIMAO TAITI KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = BISNAGUINHAS 300G PANCO
# item B = SACOLA PLASTICA MM BRANCA
# item A = BISNAGUINHAS 300G PANCO
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = LIMPOL DETERGENTE LOUCA NEUTRO 5LT
# item B = SACOLA PLASTICA MM BRANCA
# item A = LIMPOL DETERGENTE LOUCA NEUTRO 5LT
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = LIMPOL DETERGENTE LOUCA NEUTRO 5LT
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = MANTEIGA AVIACAO COM SAL POTE 500G
# item B = SACOLA PLASTICA MM BRANCA
# item A = MANTEIGA AVIACAO COM SAL POTE 500G
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = TOMATE GRANEL KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = BACON MINI CARDEAL PECA KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = BRILUX 5LT AGUA SANITARIA
# item B = SACOLA PLASTICA MM BRANCA
# item A = LINGUICA CALABRESA SADIA 500G
# item B = SACOLA PLASTICA MM BRANCA
# item A = LINGUICA CALABRESA SADIA 500G
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = PANO REUTILIZAVEL DURAMAX 3X58 PANO
# item B = SACOLA PLASTICA MM BRANCA
# item A = PANO REUTILIZAVEL DURAMAX 3X58 PANO
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = AZEITE EV ITALIANO ORGANICO 1L MM
# item B = SACOLA PLASTICA MM BRANCA
# item A = AZEITE EV ITALIANO ORGANICO 1L MM
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = DANONE MORANGO 1350G
# item B = SACOLA PLASTICA MM BRANCA
# item A = DORITOS NACHO 300GR
# item B = SACOLA PLASTICA MM BRANCA
# item A = ALHO KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = PH ROYAL CARE FD FD 40 ROLOS X 30M
# item B = SACOLA PLASTICA MM BRANCA
# item A = PH ROYAL CARE FD FD 40 ROLOS X 30M
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = PH ROYAL CARE FD FD 40 ROLOS X 30M
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = DESENGORDURANTE 1.1LT MEMBERS MARK
# item B = SACOLA PLASTICA MM BRANCA
# item A = DESENGORDURANTE 1.1LT MEMBERS MARK
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = DESENGORDURANTE 1.1LT MEMBERS MARK
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = PAO DE QJO COQUET 1K FORNO DE MINAS
# item B = SACOLA PLASTICA MM BRANCA
# item A = MARGARINA QUALY COM SAL 500G
# item B = SACOLA PLASTICA MM BRANCA
# item A = MARGARINA QUALY COM SAL 500G
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = LIMPOL 6X500ML DETERG LIQ NEUTRO
# item B = SACOLA PLASTICA MM BRANCA
# item A = LIMPOL 6X500ML DETERG LIQ NEUTRO
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = LIMPOL 6X500ML DETERG LIQ NEUTRO
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = AGUA SANITARIA 5LT DRAGAO
# item B = SACOLA PLASTICA MM BRANCA
# item A = CR DE LEITE NESTLE LT 300G
# item B = SACOLA PLASTICA MM BRANCA
# item A = CR DE LEITE NESTLE LT 300G
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = SUCO NATURAL ONE UVA/MACA 2L
# item B = SACOLA PLASTICA MM BRANCA
# item A = DOWNY BRISA DE VERAO CONCENTR 1.5LT
# item B = SACOLA PLASTICA MM BRANCA
# item A = DOWNY BRISA DE VERAO CONCENTR 1.5LT
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = MON BIJOU PUREZA 5LT AMAC DILUIDO
# item B = SACOLA PLASTICA MM BRANCA
# item A = MON BIJOU PUREZA 5LT AMAC DILUIDO
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = MON BIJOU PUREZA 5LT AMAC DILUIDO
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = LEITE COND MOCA SEMI LATA 405G
# item B = SACOLA PLASTICA MM BRANCA
# item A = LEITE COND MOCA SEMI LATA 405G
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = HASTES FLEXIVEIS COTONETE C/300UN
# item B = SACOLA PLASTICA MM BRANCA
# item A = HASTES FLEXIVEIS COTONETE C/300UN
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = BROCOLIS 1KG DAUCY
# item B = SACOLA PLASTICA MM BRANCA
# item A = QJ MUSS FATIAS MEMBERS MARK 200G
# item B = SACOLA PLASTICA MM BRANCA
# item A = QBOA 5LT AGUA SANITARIA
# item B = SACOLA PLASTICA MM BRANCA
# item A = QBOA 5LT AGUA SANITARIA
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = QBOA 5LT AGUA SANITARIA
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = MIL FOLHAS 200GR MEMBERS MARK
# item B = SACOLA PLASTICA MM BRANCA
# item A = MACA TURMA DA MONICA PCT
# item B = SACOLA PLASTICA MM BRANCA
# item A = QUEIJO MUSSARELA FAT 150G TIROLEZ
# item B = SACOLA PLASTICA MM BRANCA
# item A = PRESUNTO FATIADO SADIA 200G
# item B = SACOLA PLASTICA MM BRANCA
# item A = REQUEIJAO LIGHT MEMBERS MARK 500G
# item B = SACOLA PLASTICA MM BRANCA
# item A = LEITE FERMENTADO CHAMYTO 450G
# item B = SACOLA PLASTICA MM BRANCA
# item A = LIMPOL LIQ 6X500ML DETERG LIQ COCO
# item B = SACOLA PLASTICA MM BRANCA
# item A = LIMPOL LIQ 6X500ML DETERG LIQ COCO
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = LIMPOL LIQ 6X500ML DETERG LIQ COCO
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = SUCO LARANJA 900ML UNIDADE
# item B = SACOLA PLASTICA MM BRANCA
# item A = OMO LAVA ROUPAS EM PO 5.6KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = OMO LAVA ROUPAS EM PO 5.6KG
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = OLEO SOJA LIZA PET 900ML
# item B = SACOLA PLASTICA MM BRANCA
# item A = OLEO SOJA LIZA PET 900ML
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = OLEO SOJA LIZA PET 900ML
# item B = ACUC REF UNIAO 1KG
# item A = CLUB SOCIAL ORIGINAL ECON 12X24G
# item B = SACOLA PLASTICA MM BRANCA
# item A = COMFORT PRO AMACIANTE DILUIDO 5LT
# item B = SACOLA PLASTICA MM BRANCA
# item A = COMFORT PRO AMACIANTE DILUIDO 5LT
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = COMFORT PRO AMACIANTE DILUIDO 5LT
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = FJAO CAR KICALDO T1 1KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = FJAO CAR KICALDO T1 1KG
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = OREO BAUNILHA ECON 3X90G
# item B = SACOLA PLASTICA MM BRANCA
# item A = MACA LOONEY TUN MACA RASIP 1.5 KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = FILE DE TILAPIA 1KG MEMBERS MARK
# item B = SACOLA PLASTICA MM BRANCA
# item A = REQUEIJAO LIGHT CATUPIRY 500G
# item B = SACOLA PLASTICA MM BRANCA
# item A = REQUEIJAO LIGHT CATUPIRY 500G
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = PAO DE QJO CATUP 1KG CATUPIRY
# item B = SACOLA PLASTICA MM BRANCA
# item A = SUPER CANDIDA 5LT AGUA SANITARIA
# item B = SACOLA PLASTICA MM BRANCA
# item A = SUPER CANDIDA 5LT AGUA SANITARIA
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = SUPER CANDIDA 5LT AGUA SANITARIA
# item B = ACUC REF UNIAO 1KG
# item A = SUPER CANDIDA 5LT AGUA SANITARIA
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = SUPER CANDIDA 5LT AGUA SANITARIA
# item B = SACOLA PLASTICA MM CINZA
# item A = MAC INST NISSIN GAL CAIPIRA 5X85GR
# item B = SACOLA PLASTICA MM BRANCA
# item A = MAC INST NISSIN GAL CAIPIRA 5X85GR
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = PACK POMAROLA TRAD SACHET 3X320G
# item B = SACOLA PLASTICA MM BRANCA
# item A = PACK POMAROLA TRAD SACHET 3X320G
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = ACUC REF UNIAO 1KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = ACUC REF UNIAO 1KG
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = ACUC REF UNIAO 1KG
# item B = CR DE LEITE PIRACANJUBA TP 200G
# item A = ACUC REF UNIAO 1KG
# item B = OLEO SOJA LIZA PET 900ML
# item A = ACUC REF UNIAO 1KG
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = QUEIJO MINAS PADRAO REGINA KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = OVINHOS DE AMENDOIM 400G
# item B = SACOLA PLASTICA MM BRANCA
# item A = GOMA TAPIOCA 1 KG DOCE MEL
# item B = SACOLA PLASTICA MM BRANCA
# item A = GOMA PARA TAPIOCA GOMA DE TAPIOCA 1
# item B = SACOLA PLASTICA MM BRANCA
# item A = GOMA PARA TAPIOCA GOMA DE TAPIOCA 1
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = PAO FORMA 480G PLUS VITA
# item B = SACOLA PLASTICA MM BRANCA
# item A = LEITE CONDENSADO TP 395G PIRACANJ
# item B = SACOLA PLASTICA MM BRANCA
# item A = LEITE CONDENSADO TP 395G PIRACANJ
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = LEITE CONDENSADO TP 395G PIRACANJ
# item B = CR DE LEITE PIRACANJUBA TP 200G
# item A = BEB LAC YOPRO CHOCOLATE 250ML
# item B = SACOLA PLASTICA MM BRANCA
# item A = KETCHUP TRADICIONAL HEMMER 1 KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = PRESUNTO FATIADO 200 GR
# item B = SACOLA PLASTICA MM BRANCA
# item A = ABACATE KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = FJAO CAR CAMIL T1 1KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = FJAO CAR CAMIL T1 1KG
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = AZEITE GALLO EXTRA VIRGEM 750ML
# item B = SACOLA PLASTICA MM BRANCA
# item A = AZEITE GALLO EXTRA VIRGEM 750ML
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = MINI OREO 10X35G
# item B = SACOLA PLASTICA MM BRANCA
# item A = BISC POLV QUEIJO 200G MEMBERS MARK
# item B = SACOLA PLASTICA MM BRANCA
# item A = YPE LIQ 6X500ML DETERG LIQ NEUTRO
# item B = SACOLA PLASTICA MM BRANCA
# item A = YPE LIQ 6X500ML DETERG LIQ NEUTRO
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = BIS LEITE 3X126G
# item B = SACOLA PLASTICA MM BRANCA
# item A = AZEITE RAHMA EXTRA VIRGEM 1LT
# item B = SACOLA PLASTICA MM BRANCA
# item A = AZEITE RAHMA EXTRA VIRGEM 1LT
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = LENCO UMED MAMYPOKO T SUAVE 4X50UN
# item B = SACOLA PLASTICA MM BRANCA
# item A = CREME DE LEITE TP ITALAC 200G
# item B = SACOLA PLASTICA MM BRANCA
# item A = PAO DE FORMA 480G PULLMAN
# item B = SACOLA PLASTICA MM BRANCA
# item A = FILE MIGN S CORDAO KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = VEJA LIMPEZA PESADA CLORO 2X1LT
# item B = SACOLA PLASTICA MM BRANCA
# item A = VEJA LIMPEZA PESADA CLORO 2X1LT
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = PAO MEL SCHOKOL 500G MEMBERS MARK
# item B = SACOLA PLASTICA MM BRANCA
# item A = PAPEL FILME MM 27.5CM X 120M
# item B = SACOLA PLASTICA MM BRANCA
# item A = PAPEL FILME MM 27.5CM X 120M
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = MINAS PADRAO LACFREE ZERO LACTOSE K
# item B = SACOLA PLASTICA MM BRANCA
# item A = PAO DE QJO TRAD 1KG MEMBERS MARK
# item B = SACOLA PLASTICA MM BRANCA
# item A = AGUA SANITARIA YPE AGUA SAN. 5LTS
# item B = SACOLA PLASTICA MM BRANCA
# item A = FANDANGOS PRESUNTO 230GR
# item B = SACOLA PLASTICA MM BRANCA
# item A = FILE DE PEITO FRANG MEMBERS MARK KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = MOLHO TOMATE TRAD. HEINZ 1.020 KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = TOMATE BOMBOM BDJ 500G
# item B = SACOLA PLASTICA MM BRANCA
# item A = TODDY ORIGINAL 1.800KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = TOMATE PELADO CIRIO 3 X 400G
# item B = SACOLA PLASTICA MM BRANCA
# item A = TOMATE PELADO CIRIO 3 X 400G
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = LIMAO PCT 1KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = PACK EXTRE/NRISCA PK MISTO C/10UNID
# item B = SACOLA PLASTICA MM BRANCA
# item A = PACK EXTRE/NRISCA PK MISTO C/10UNID
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = MELAO DOCE REDINHA KG
# item B = SACOLA PLASTICA MM BRANCA
# item A = LINGUICA FININHA MISTA 240G
# item B = SACOLA PLASTICA MM BRANCA
# item A = ABACAXI PEROLA UNIDADE
# item B = SACOLA PLASTICA MM BRANCA
# item A = OLEO SOJA SOYA PET 900ML
# item B = SACOLA PLASTICA MM BRANCA
# item A = TORRADA TRAD.M.PACK 284GR
# item B = SACOLA PLASTICA MM BRANCA
# item A = SOBRECOXA SADIA 1KG ZIP IQF
# item B = SACOLA PLASTICA MM BRANCA
# item A = BIS BRANCO 3X126GR
# item B = SACOLA PLASTICA MM BRANCA
# item A = QJ PARMESAO F AZUL CILINDRO VIGOR 1
# item B = SACOLA PLASTICA MM BRANCA
# item A = SABONETE DOVE ORIGINAL 8X90G
# item B = SACOLA PLASTICA MM BRANCA
# item A = SABONETE DOVE ORIGINAL 8X90G
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = OLEO GIRASSOL SALADA PET 900ML
# item B = SACOLA PLASTICA MM BRANCA
# item A = OLEO GIRASSOL SALADA PET 900ML
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = TORRADA MULTIGRAO 284GR M.PACK
# item B = SACOLA PLASTICA MM BRANCA
# item A = SACOLA PLASTICA MM CINZA
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = SACOLA PLASTICA MM CINZA
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = SAL REF CISNE 1KG
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = SAL REF CISNE 1KG
# item B = OLEO SOJA LIZA PET 900ML
# item A = SAL REF CISNE 1KG
# item B = ACUC REF UNIAO 1KG
# item A = AGUA SANITARIA 5LT MEMBERS MARK
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = AGUA SANITARIA 5LT MEMBERS MARK
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN
# item A = GUARD MASCOT FD 200FLS
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = SACOLA PLASTICA MM VERDE
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = PATO GERMINEX MARINE 3X500ML
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = VEJA LAVANDA 4LT LIMPADOR PERFUMADO
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = GUARD GRAN HOTEL COQUETEL FD 9X50FL
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = MANTEIGA TABLETE C/SAL 200G
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = FILTRO DE PAPEL120UN MM TAM 102
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = CREME DENTAL T0TAL 12 CLEAN 4X90G
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = BRILHANTE LAVA ROUPAS BCO E COL 4KG
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = KALIPTO 5LT DESINFETANTE 5LT
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = VANISH 3 LT COLORS TIRA MANCHAS
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = LYSOFORM BRUTO DESINFETANTE 5LT
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = ACUC DEME ORGANICO NATIVE 1KG
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = SAPOLIO RADIUM 2X450ML
# item B = PAPEL TOALHA KITCHEN JUMB FD C360FL
# item A = MM MULTIUSO 1.1LT
# item B = MM LAVA ROUPAS 5LTS ULTIMATE CLEAN

# %%
df_support_A_B_C = pd.DataFrame.from_dict(dic_support_A_B_C, orient = 'index')
df_support_A_B_C
# Out:
#                                                     PH NEVE FT 20M L32P28UN  \
# SACOLA PLASTICA MM BRANCA-PAPEL TOALHA KITCHEN ...                 0.000226
# PAPEL TOALHA KITCHEN JUMB FD C360FL-SACOLA PLAS...                 0.000226
# PH NEVE FT 20M L32P28UN-SACOLA PLASTICA MM BRANCA                       NaN
# PH NEVE FT 20M L32P28UN-PAPEL TOALHA KITCHEN JU...                      NaN
# PH PERSONAL VIP FD 40 ROLOSX30M-PAPEL TOALHA KI...                      NaN
#
#                                                     PAPEL TOALHA KITCHEN JUMB FD C360FL  \
# SACOLA PLASTICA MM BRANCA-PAPEL TOALHA KITCHEN ...                                  NaN
# PAPEL TOALHA KITCHEN JUMB FD C360FL-SACOLA PLAS...                                  NaN
# PH NEVE FT 20M L32P28UN-SACOLA PLASTICA MM BRANCA                              0.000224
# PH NEVE FT 20M L32P28UN-PAPEL TOALHA KITCHEN JU...                                  NaN
# PH PERSONAL VIP FD 40 ROLOSX30M-PAPEL TOALHA KI...                                  NaN
#
#                                                     SACOLA PLASTICA MM BRANCA
# SACOLA PLASTICA MM BRANCA-PAPEL TOALHA KITCHEN ...                        NaN
# PAPEL TOALHA KITCHEN JUMB FD C360FL-SACOLA PLAS...                        NaN
# PH NEVE FT 20M L32P28UN-SACOLA PLASTICA MM BRANCA                         NaN
# PH NEVE FT 20M L32P28UN-PAPEL TOALHA KITCHEN JU...                   0.000249
# PH PERSONAL VIP FD 40 ROLOSX30M-PAPEL TOALHA KI...                   0.000222

# %%
df_support_A_B_C = pd.DataFrame.from_dict(dic_support_A_B_C, orient = 'index')
colunas = df_support_A_B_C.columns

df_support_A_B_C.reset_index(inplace = True)
df_support_A_B_C.rename(columns = {'index': 'A-B'}, inplace = True)
df_support_A_B_C['A'] = df_support_A_B_C['A-B'].str.split('-', expand = True)[0]
df_support_A_B_C['B'] = df_support_A_B_C['A-B'].str.split('-', expand = True)[1]
df_support_A_B_C.drop(labels = 'A-B', axis = 1, inplace = True)

df_support_A_B_C = pd.melt(df_support_A_B_C, id_vars = ['A', 'B'], value_vars = colunas)
df_support_A_B_C.rename(columns = {'variable':'C'}, inplace = True)
df_support_A_B_C.dropna(inplace = True)

df_support_A_B_C.reset_index(drop = True, inplace = True)

# %%
df_support_A_B_C
# Out:
#                                      A                                    B  \
# 0            SACOLA PLASTICA MM BRANCA  PAPEL TOALHA KITCHEN JUMB FD C360FL
# 1  PAPEL TOALHA KITCHEN JUMB FD C360FL            SACOLA PLASTICA MM BRANCA
# 2              PH NEVE FT 20M L32P28UN            SACOLA PLASTICA MM BRANCA
# 3              PH NEVE FT 20M L32P28UN  PAPEL TOALHA KITCHEN JUMB FD C360FL
# 4      PH PERSONAL VIP FD 40 ROLOSX30M  PAPEL TOALHA KITCHEN JUMB FD C360FL
#
#                                      C     value
# 0              PH NEVE FT 20M L32P28UN  0.000226
# 1              PH NEVE FT 20M L32P28UN  0.000226
# 2  PAPEL TOALHA KITCHEN JUMB FD C360FL  0.000224
# 3            SACOLA PLASTICA MM BRANCA  0.000249
# 4            SACOLA PLASTICA MM BRANCA  0.000222
